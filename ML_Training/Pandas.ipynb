# %%
# DataFrame has 1 column that is Series
# More than 1 Series that is called DataFrame
# jose portilla : Data Scientist

# %%
import pandas as pd
import numpy as np

# %%
labels=['a','b','c']
values=[15,20,17]
arr=np.array([23,65,3])

# %%
pd.Series(values)
# Out:
# 0    15
# 1    20
# 2    17
# dtype: int64

# %%
pd.Series(values,labels)
# Out:
# a    15
# b    20
# c    17
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    23
# 1    65
# 2     3
# dtype: int32

# %%
pd.Series([sum,print,len])
# Out:
# 0      <built-in function sum>
# 1    <built-in function print>
# 2      <built-in function len>
# dtype: object

# %%
pd.Series(arr,['first','second','third'])
# Out:
# first     23
# second    65
# third      3
# dtype: int32

# %%
pand_return=pd.Series(arr,['first','second','third'])

# %%
pand_return['first']
# Out:
# 23

# %%
dictionary={'a':7, 'b':8}

# %%
dictionary
# Out:
# {'a': 7, 'b': 8}

# %%
pd.Series(dictionary)
# Out:
# a    7
# b    8
# dtype: int64

# %%
ser1=pd.Series([32,54,23,76],index=['india','Pak','US','China'])

# %%
ser1
# Out:
# india    32
# Pak      54
# US       23
# China    76
# dtype: int64

# %%
ser2=pd.Series([32,54,23,76],index=['india','Lanka','US','China'])

# %%
ser1+ser2
# Out:
# China    152.0
# Lanka      NaN
# Pak        NaN
# US        46.0
# india     64.0
# dtype: float64

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.DataFrame(np.random.randn(5,4))
# Out:
#           0         1         2         3
# 0  0.220577 -1.909393 -0.670447 -1.444046
# 1 -0.851442  1.557893  0.242007 -0.594174
# 2 -1.012816 -0.469556  0.035164  0.526550
# 3  1.245090  0.148477  1.163837  0.108914
# 4 -0.125399 -0.820718 -1.237981  0.630915

# %%
pd.DataFrame(np.random.randn(5,4),['A','B','C','D','E'],['W','X','Y','Z'])
# Out:
#           W         X         Y         Z
# A  0.670471 -2.595567 -0.806821 -0.394668
# B -1.456085 -1.460058  1.144402 -0.712792
# C -1.396644 -1.573200 -0.788650 -0.954495
# D -0.282574  0.421010 -0.500182  0.635040
# E  1.794604  0.154848  1.013811  0.245638

# %%
df=pd.DataFrame(np.random.randn(5,4),['A','B','C','D','E'],['W','X','Y','Z'])

# %%
df
# Out:
#           W         X         Y         Z
# A  0.466943 -0.321030  0.610522 -0.258528
# B  0.078714 -1.191858  1.549987 -1.614646
# C  0.300912 -0.220022 -0.231814  1.521201
# D -0.198705 -0.041693 -0.012841  1.038811
# E -2.255202 -0.716639  1.040204 -2.110169

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['W']
# Out:
# A    0.466943
# B    0.078714
# C    0.300912
# D   -0.198705
# E   -2.255202
# Name: W, dtype: float64

# %%
df[['W','X']]
# Out:
#           W         X
# A  0.466943 -0.321030
# B  0.078714 -1.191858
# C  0.300912 -0.220022
# D -0.198705 -0.041693
# E -2.255202 -0.716639

# %%
df.W
# Out:
# A    0.466943
# B    0.078714
# C    0.300912
# D   -0.198705
# E   -2.255202
# Name: W, dtype: float64

# %%
df['NEW']=df['X']+df['Y']

# %%
df
# Out:
#           W         X         Y         Z       NEW
# A  0.466943 -0.321030  0.610522 -0.258528  0.289492
# B  0.078714 -1.191858  1.549987 -1.614646  0.358129
# C  0.300912 -0.220022 -0.231814  1.521201 -0.451836
# D -0.198705 -0.041693 -0.012841  1.038811 -0.054534
# E -2.255202 -0.716639  1.040204 -2.110169  0.323565

# %%
#Axis =0 for indexes deletion
#Axis =1 for columns deletion
df.drop('NEW',axis=1)
# Out:
#           W         X         Y         Z
# A  0.466943 -0.321030  0.610522 -0.258528
# B  0.078714 -1.191858  1.549987 -1.614646
# C  0.300912 -0.220022 -0.231814  1.521201
# D -0.198705 -0.041693 -0.012841  1.038811
# E -2.255202 -0.716639  1.040204 -2.110169

# %%
df
# Out:
#           W         X         Y         Z       NEW
# A  0.466943 -0.321030  0.610522 -0.258528  0.289492
# B  0.078714 -1.191858  1.549987 -1.614646  0.358129
# C  0.300912 -0.220022 -0.231814  1.521201 -0.451836
# D -0.198705 -0.041693 -0.012841  1.038811 -0.054534
# E -2.255202 -0.716639  1.040204 -2.110169  0.323565

# %%
#inplace=True for permanent deletion
df.drop('NEW',axis=1,inplace=True)

# %%
df
# Out:
#           W         X         Y         Z
# A  0.466943 -0.321030  0.610522 -0.258528
# B  0.078714 -1.191858  1.549987 -1.614646
# C  0.300912 -0.220022 -0.231814  1.521201
# D -0.198705 -0.041693 -0.012841  1.038811
# E -2.255202 -0.716639  1.040204 -2.110169

# %%
df.loc['B']
# Out:
# W    0.078714
# X   -1.191858
# Y    1.549987
# Z   -1.614646
# Name: B, dtype: float64

# %%
type(df.loc['B'])
# Out:
# pandas.core.series.Series

# %%
df.iloc[1]
# Out:
# W    0.078714
# X   -1.191858
# Y    1.549987
# Z   -1.614646
# Name: B, dtype: float64

# %%
df.iloc[1:3]
# Out:
#           W         X         Y         Z
# B  0.078714 -1.191858  1.549987 -1.614646
# C  0.300912 -0.220022 -0.231814  1.521201

# %%
df.iloc[1:3][0:1]
# Out:
#           W         X         Y         Z
# B  0.078714 -1.191858  1.549987 -1.614646

# %%
df
# Out:
#           W         X         Y         Z
# A  0.466943 -0.321030  0.610522 -0.258528
# B  0.078714 -1.191858  1.549987 -1.614646
# C  0.300912 -0.220022 -0.231814  1.521201
# D -0.198705 -0.041693 -0.012841  1.038811
# E -2.255202 -0.716639  1.040204 -2.110169

# %%
df.iloc[2:]
# Out:
#           W         X         Y         Z
# C  0.300912 -0.220022 -0.231814  1.521201
# D -0.198705 -0.041693 -0.012841  1.038811
# E -2.255202 -0.716639  1.040204 -2.110169

# %%
df.iloc[2:,0:1]
# Out:
#           W
# C  0.300912
# D -0.198705
# E -2.255202

# %%
df.iloc[2:,0:2]
# Out:
#           W         X
# C  0.300912 -0.220022
# D -0.198705 -0.041693
# E -2.255202 -0.716639

# %%
df
# Out:
#           W         X         Y         Z
# A  0.466943 -0.321030  0.610522 -0.258528
# B  0.078714 -1.191858  1.549987 -1.614646
# C  0.300912 -0.220022 -0.231814  1.521201
# D -0.198705 -0.041693 -0.012841  1.038811
# E -2.255202 -0.716639  1.040204 -2.110169

# %%
df.loc['A','W']
# Out:
# 0.4669431776922263

# %%
df.loc[['A','B']]
# Out:
#           W         X         Y         Z
# A  0.466943 -0.321030  0.610522 -0.258528
# B  0.078714 -1.191858  1.549987 -1.614646

# %%
df.loc[['A','B'],['W','X']]
# Out:
#           W         X
# A  0.466943 -0.321030
# B  0.078714 -1.191858

# %%
df>0
# Out:
#        W      X      Y      Z
# A   True  False   True  False
# B   True  False   True  False
# C   True  False  False   True
# D  False  False  False   True
# E  False  False   True  False

# %%
df[df>0]
# Out:
#           W   X         Y         Z
# A  0.466943 NaN  0.610522       NaN
# B  0.078714 NaN  1.549987       NaN
# C  0.300912 NaN       NaN  1.521201
# D       NaN NaN       NaN  1.038811
# E       NaN NaN  1.040204       NaN

# %%
df
# Out:
#           W         X         Y         Z
# A  0.466943 -0.321030  0.610522 -0.258528
# B  0.078714 -1.191858  1.549987 -1.614646
# C  0.300912 -0.220022 -0.231814  1.521201
# D -0.198705 -0.041693 -0.012841  1.038811
# E -2.255202 -0.716639  1.040204 -2.110169

# %%
df[df['Y']>0]
# Out:
#           W         X         Y         Z
# A  0.466943 -0.321030  0.610522 -0.258528
# B  0.078714 -1.191858  1.549987 -1.614646
# E -2.255202 -0.716639  1.040204 -2.110169

# %%
df['Y']>0
# Out:
# A     True
# B     True
# C    False
# D    False
# E     True
# Name: Y, dtype: bool

# %%
#Resetting index
df.reset_index()
# Out:
#   index         W         X         Y         Z
# 0     A  0.466943 -0.321030  0.610522 -0.258528
# 1     B  0.078714 -1.191858  1.549987 -1.614646
# 2     C  0.300912 -0.220022 -0.231814  1.521201
# 3     D -0.198705 -0.041693 -0.012841  1.038811
# 4     E -2.255202 -0.716639  1.040204 -2.110169

# %%
df.columns
# Out:
# Index(['W', 'X', 'Y', 'Z'], dtype='object')

# %%
df['new']=['USA','IND','SL','PK','VK']

# %%
df.set_index('new',drop=True)
# Out:
#             W         X         Y         Z
# new
# USA  0.466943 -0.321030  0.610522 -0.258528
# IND  0.078714 -1.191858  1.549987 -1.614646
# SL   0.300912 -0.220022 -0.231814  1.521201
# PK  -0.198705 -0.041693 -0.012841  1.038811
# VK  -2.255202 -0.716639  1.040204 -2.110169

# %%
df.set_index('new',drop=True,inplace=True)

# %%
df.columns
# Out:
# Index(['W', 'X', 'Y', 'Z'], dtype='object')

# %%
# Out:
# <bound method NDFrame.head of             W         X         Y         Z
# new
# USA  0.466943 -0.321030  0.610522 -0.258528
# IND  0.078714 -1.191858  1.549987 -1.614646
# SL   0.300912 -0.220022 -0.231814  1.521201
# PK  -0.198705 -0.041693 -0.012841  1.038811
# VK  -2.255202 -0.716639  1.040204 -2.110169>

# %%
df=df[df>0]

# %%
df
# Out:
#             W   X         Y         Z
# new
# USA  0.466943 NaN  0.610522       NaN
# IND  0.078714 NaN  1.549987       NaN
# SL   0.300912 NaN       NaN  1.521201
# PK        NaN NaN       NaN  1.038811
# VK        NaN NaN  1.040204       NaN

# %%
df.fillna(value="Rambabu")
# Out:
#              W        X         Y        Z
# new
# USA   0.466943  Rambabu  0.610522  Rambabu
# IND  0.0787141  Rambabu   1.54999  Rambabu
# SL    0.300912  Rambabu   Rambabu   1.5212
# PK     Rambabu  Rambabu   Rambabu  1.03881
# VK     Rambabu  Rambabu    1.0402  Rambabu

# %%
df['W'].fillna(df['W'].mean())
# Out:
# new
# USA    0.466943
# IND    0.078714
# SL     0.300912
# PK     0.282190
# VK     0.282190
# Name: W, dtype: float64

# %%
ipl_data = {'Team': ['Riders', 'Riders', 'Devils', 'Devils', 'Kings',
         'kings', 'Kings', 'Kings', 'Riders', 'Royals', 'Royals', 'Riders'],
         'Rank': [1, 2, 2, 3, 3,4 ,1 ,1,2 , 4,1,2],
         'Year': [2014,2015,2014,2015,2014,2015,2016,2017,2016,2014,2015,2017],
         'Points':[876,789,863,673,741,812,756,788,694,701,804,690]}

# %%
df=pd.DataFrame(ipl_data)

# %%
df
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 5    kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690

# %%
df_groupby=df.groupby('Team')

# %%
df_groupby.mean()
# Out:
#             Rank         Year      Points
# Team
# Devils  2.500000  2014.500000  768.000000
# Kings   1.666667  2015.666667  761.666667
# Riders  1.750000  2015.500000  762.250000
# Royals  2.500000  2014.500000  752.500000
# kings   4.000000  2015.000000  812.000000

# %%
df_groupby.std()
# Out:
#             Rank      Year      Points
# Team
# Devils  0.707107  0.707107  134.350288
# Kings   1.154701  1.527525   24.006943
# Riders  0.500000  1.290994   88.567771
# Royals  2.121320  0.707107   72.831998
# kings        NaN       NaN         NaN

# %%
df_groupby.min()
# Out:
#         Rank  Year  Points
# Team
# Devils     2  2014     673
# Kings      1  2014     741
# Riders     1  2014     690
# Royals     1  2014     701
# kings      4  2015     812

# %%
df_groupby.describe()
# Out:
#        Points                                                               \
#         count        mean         std    min     25%    50%     75%    max
# Team
# Devils    2.0  768.000000  134.350288  673.0  720.50  768.0  815.50  863.0
# Kings     3.0  761.666667   24.006943  741.0  748.50  756.0  772.00  788.0
# Riders    4.0  762.250000   88.567771  690.0  693.00  741.5  810.75  876.0
# Royals    2.0  752.500000   72.831998  701.0  726.75  752.5  778.25  804.0
# kings     1.0  812.000000         NaN  812.0  812.00  812.0  812.00  812.0
#
#         Rank             ...               Year                         \
#        count      mean   ...     75%  max count         mean       std
# Team                     ...
# Devils   2.0  2.500000   ...    2.75  3.0   2.0  2014.500000  0.707107
# Kings    3.0  1.666667   ...    2.00  3.0   3.0  2015.666667  1.527525
# Riders   4.0  1.750000   ...    2.00  2.0   4.0  2015.500000  1.290994
# ...

# %%
#Read CSV

# %%
df=pd.read_csv('C:\ent\Zegami_60_20190117.csv')

# %%
df
# Out:
#         ID   Treatment                                          ImageName  \
# 0   190001      Purge1  VIS_V_190001_190117125122347_RGB-SideBottom-18...
# 1   190002      Purge1  VIS_V_190002_190117125122347_RGB-SideBottom-18...
# 2   190003  Saturation  VIS_V_190003_190117125122347_RGB-SideBottom-18...
# 3   190004  Saturation  VIS_V_190004_190117125122347_RGB-SideBottom-18...
# 4   190005  Saturation  VIS_V_190005_190117125122347_RGB-SideBottom-18...
# 5   190006  Saturation  VIS_V_190006_190117125122347_RGB-SideBottom-18...
# 6   190007  Saturation  VIS_V_190007_190117125122347_RGB-SideBottom-18...
# 7   190008  Saturation  VIS_V_190008_190117125122347_RGB-SideBottom-18...
# 8   190009  Saturation  VIS_V_190009_190117125122347_RGB-SideBottom-18...
# 9   190010  Saturation  VIS_V_190010_190117125122347_RGB-SideBottom-18...
# 10  190011  Saturation  VIS_V_190011_190117125122347_RGB-SideBottom-18...
# 11  190012  Saturation  VIS_V_190012_190117125122347_RGB-SideBottom-18...
# ...

# %%
df_json=pd.read_excel('C:\PSTL\Purdue_PSTL\SMS\POC\SoundScape\charlie\Content_Description_20180808.xlsx')

# %%
df_json
# Out:
#            Old Database              Unnamed: 1  \
# 0                 Table                  Column
# 1           collections                   ColID
# 2           collections                  Author
# 3           collections              FileSource
# 4           collections          CollectionName
# 5           collections  CollectionFullCitation
# 6           collections                 MiscURL
# 7           collections                   Notes
# 8                   NaN                     NaN
# 9           collections           Total Records
# 10              colsite                   ColID
# 11              colsite                  SiteID
# 12              colsite           Total Records
# 13          pumiliuolog                   LogID
# 14          pumiliuolog                  UserID
# 15          pumiliuolog                 LogType
# 16          pumiliuolog                 SoundID
# 17          pumiliuolog                 LogText
# ...

# %%
df_json.head()
# Out:
#   Old Database      Unnamed: 1  \
# 0        Table          Column
# 1  collections           ColID
# 2  collections          Author
# 3  collections      FileSource
# 4  collections  CollectionName
#
#                                           Unnamed: 2  \
# 0                                     First 5 Values
# 1                                      1\n2\n3\n4\n5
# 2  NA\nNA\nNA\nAmandine Gasc\nTropical Ecosystem ...
# 3  [blank]\nAutomated Audio Logger\nAutomated Aud...
# 4  Hoosier Electric\nLeopold Reserve\nChicago Dat...
#
#                                           Unnamed: 3  \
# 0                                     Example Values
# 1                                    1\n2\n3\n16\n17
# 2  NA\nAmandine Gasc\nTropical Ecosystem Assessme...
# 3  [blank]\nAutomated Audio Logger\nAutomated Aud...
# 4  Hoosier Electric\nLeopold Reserve\nChicago Dat...
#
#                                           Unnamed: 4  \
# 0                                        Description
# ...

# %%
#converting to csv
df_json.to_csv(('C:\PSTL\Purdue_PSTL\SMS\POC\SoundScape\charlie\Content_Description_20180808.csv'))

# %%
#https://www.fdic.gov/bank/individual/failed/banklist.html

# %%
pd.read_html('C:\ent\FDIC_ Failed Bank List.html')[0]
# Out:
#                                             Bank Name                City  ST  \
# 0                 Washington Federal Bank for Savings             Chicago  IL
# 1     The Farmers and Merchants State Bank of Argonia             Argonia  KS
# 2                                 Fayette County Bank          Saint Elmo  IL
# 3   Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee  WI
# 4                                      First NBC Bank         New Orleans  LA
# 5                                       Proficio Bank  Cottonwood Heights  UT
# 6                       Seaway Bank and Trust Company             Chicago  IL
# 7                              Harvest Community Bank          Pennsville  NJ
# 8                                         Allied Bank            Mulberry  AR
# 9                        The Woodbury Banking Company            Woodbury  GA
# 10                             First CornerStone Bank     King of Prussia  PA
# ...

# %%
# Population and Sample
